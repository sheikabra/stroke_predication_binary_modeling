# %% [markdown]
# <a href="https://colab.research.google.com/github/sheikabra/stroke_predication_binary_modeling/blob/main/stroke_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stroke Preidiction
# ##### by: Abrahim Hussain
# ###### data from: FEDESORIANO (https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### 1.1: Data Collection

# %%
df = pd.read_csv("healthcare-dataset-stroke-data.csv")

# %%
df
# Out:
#          id  gender   age  hypertension  ...  avg_glucose_level   bmi   smoking_status stroke
# 0      9046    Male  67.0             0  ...             228.69  36.6  formerly smoked      1
# 1     51676  Female  61.0             0  ...             202.21   NaN     never smoked      1
# 2     31112    Male  80.0             0  ...             105.92  32.5     never smoked      1
# 3     60182  Female  49.0             0  ...             171.23  34.4           smokes      1
# 4      1665  Female  79.0             1  ...             174.12  24.0     never smoked      1
# ...     ...     ...   ...           ...  ...                ...   ...              ...    ...
# 5105  18234  Female  80.0             1  ...              83.75   NaN     never smoked      0
# 5106  44873  Female  81.0             0  ...             125.20  40.0     never smoked      0
# 5107  19723  Female  35.0             0  ...              82.99  30.6     never smoked      0
# ...

# %%
missing_values = df.where(df.isnull()).any(axis=1).sum()
missing_values
# Out:
# 0

# %%
df['gender'].nunique()
# Out:
# 3

# %%
group_by_gender = df.groupby('gender').sum()
group_by_gender
# Out:
#                id        age  ...                                     smoking_status  stroke
# gender                        ...
# Female  109220177  131009.64  ...  never smokedsmokesnever smokednever smokedUnkn...     141
# Male     77329775   89852.36  ...  formerly smokednever smokedformerly smokedneve...     108
# Other       56156      26.00  ...                                    formerly smoked       0
#
# [3 rows x 11 columns]

# %%
target = "stroke"
numerical_column = df.columns.drop(target)
output_row = df[target]
df.drop(target, axis=1, inplace=True)

# %%
keep_columns = ['gender', 'hypertension', 'heart_disease']
df = df[keep_columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-5854656b7a33> in <cell line: 1>()
# ----> 1 df['gender'].replace(to_replace=dict(male=1,female=0), inplace=True)
#
# AttributeError: 'bool' object has no attribute 'replace'

# %%
df.loc[df['gender']]
# Out:
# 0            1
# 1            0
# 2            1
# 3            0
# 4            0
#           ...
# 5106         0
# 5107         0
# 5108         1
# 5109         0
# gender    True
# Name: gender, Length: 5111, dtype: object

# %% [markdown]
# ### Data Preprocessing

# %%
scaler = MinMaxScaler()
scaler.fit(df)
t_df = scaler.transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-4cda703c02e8> in <cell line: 2>()
#       1 scaler = MinMaxScaler()
# ----> 2 scaler.fit(df)
#       3 t_df = scaler.transform(df)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     425         # Reset internal state before fitting
#     426         self._reset()
# --> 427         return self.partial_fit(X, y)
#     428
#     429     def partial_fit(self, X, y=None):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     464
#     465         first_pass = not hasattr(self, "n_samples_seen_")
# --> 466         X = self._validate_data(
#     467             X,
#     468             reset=first_pass,
#
# ...
